# %% [markdown]
# # Exploratory Data Analysis with Pandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df_property = pd.read_csv("./data/property_data.csv")
print("num of rows:", df_property.shape[0])
print("num of cols:", df_property.shape[1])

df_property
# Out:
# num of rows: 9
# num of cols: 7
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y           --        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df_property.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PID           8 non-null      float64
#  1   ST_NUM        7 non-null      float64
#  2   ST_NAME       9 non-null      object
#  3   OWN_OCCUPIED  8 non-null      object
#  4   NUM_BEDROOMS  7 non-null      object
#  5   NUM_BATH      8 non-null      object
#  6   SQ_FT         8 non-null      object
# dtypes: float64(2), object(5)
# memory usage: 632.0+ bytes

# %% [markdown]
# ## Missing Values

# %%
df_property.loc[df_property["PID"].isna(), "PID"] = 100005000

# %%
df_property["PID"] = df_property["PID"].astype("int")

# %%
df_property
# Out:
#          PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000   104.0      PUTNAM            Y            3        1  1000
# 1  100002000   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000   201.0    BERKELEY           12            1      NaN   700
# 4  100005000   203.0    BERKELEY            Y            3        2  1600
# 5  100006000   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000   213.0     TREMONT            Y           --        1   NaN
# 8  100009000   215.0     TREMONT            Y           na        2  1800

# %%
df_property["OWN_OCCUPIED"]
# Out:
# 0      Y
# 1      N
# 2      N
# 3     12
# 4      Y
# 5      Y
# 6    NaN
# 7      Y
# 8      Y
# Name: OWN_OCCUPIED, dtype: object

# %%
for row, value in enumerate(df_property["OWN_OCCUPIED"]):
    try:
        int(value)
        df_property.loc[row, "OWN_OCCUPIED"] = np.nan
    except ValueError:
        print(f"Value {value} is fine! Continue...")
# Out:
# Value Y is fine! Continue...
# Value N is fine! Continue...
# Value N is fine! Continue...
# Value Y is fine! Continue...
# Value Y is fine! Continue...
# Value nan is fine! Continue...
# Value Y is fine! Continue...
# Value Y is fine! Continue...

# %%
df_property.loc[1, "ST_NUM"] = np.nan
# Out:
#          PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000   104.0      PUTNAM            Y            3        1  1000
# 1  100002000   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000   201.0    BERKELEY          NaN            1      NaN   700
# 4  100005000   203.0    BERKELEY            Y            3        2  1600
# 5  100006000   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000   213.0     TREMONT            Y           --        1   NaN
# 8  100009000   215.0     TREMONT            Y           na        2  1800

# %%
for row, value in enumerate(df_property["NUM_BEDROOMS"]):
    try:
        int(value)
        print(f"Value {value} is fine! Continue...")
    except ValueError:
        df_property.loc[row, "NUM_BEDROOMS"] = np.nan
# Out:
# Value 3 is fine! Continue...
# Value 3 is fine! Continue...
# Value 1 is fine! Continue...
# Value 3 is fine! Continue...
# Value 2 is fine! Continue...

# %%
df_property
# Out:
#          PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000   104.0      PUTNAM            Y            3        1  1000
# 1  100002000   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000   201.0    BERKELEY          NaN            1      NaN   700
# 4  100005000   203.0    BERKELEY            Y            3        2  1600
# 5  100006000   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000   213.0     TREMONT            Y          NaN        1   NaN
# 8  100009000   215.0     TREMONT            Y          NaN        2  1800

# %%
for row, value in enumerate(df_property["NUM_BATH"]):
    try:
        float(value)
        print(f"Value {value} is fine! Continue...")
    except ValueError:
        df_property.loc[row, "NUM_BATH"] = np.nan
# Out:
# Value 1 is fine! Continue...
# Value 1.5 is fine! Continue...
# Value 1 is fine! Continue...
# Value nan is fine! Continue...
# Value 2 is fine! Continue...
# Value 1 is fine! Continue...
# Value 1 is fine! Continue...
# Value 2 is fine! Continue...

# %%
df_property
# Out:
#          PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000   104.0      PUTNAM            Y            3        1  1000
# 1  100002000   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000   201.0    BERKELEY          NaN            1      NaN   700
# 4  100005000   203.0    BERKELEY            Y            3        2  1600
# 5  100006000   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000     NaN  WASHINGTON          NaN            2      NaN   950
# 7  100008000   213.0     TREMONT            Y          NaN        1   NaN
# 8  100009000   215.0     TREMONT            Y          NaN        2  1800

# %%
for row, value in enumerate(df_property["SQ_FT"]):
    try:
        float(value)
        print(f"Value {value} is fine! Continue...")
    except ValueError:
        df_property.loc[row, "SQ_FT"] = np.nan
# Out:
# Value 1000 is fine! Continue...
# Value 850 is fine! Continue...
# Value 700 is fine! Continue...
# Value 1600 is fine! Continue...
# Value 800 is fine! Continue...
# Value 950 is fine! Continue...
# Value nan is fine! Continue...
# Value 1800 is fine! Continue...

# %%
df_property
# Out:
#          PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000   104.0      PUTNAM            Y            3        1  1000
# 1  100002000   197.0   LEXINGTON            N            3      1.5   NaN
# 2  100003000     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000   201.0    BERKELEY          NaN            1      NaN   700
# 4  100005000   203.0    BERKELEY            Y            3        2  1600
# 5  100006000   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000     NaN  WASHINGTON          NaN            2      NaN   950
# 7  100008000   213.0     TREMONT            Y          NaN        1   NaN
# 8  100009000   215.0     TREMONT            Y          NaN        2  1800

# %%
# !pip install xlrd
# Out:
# Collecting xlrd
#   Using cached xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-1.2.0
# WARNING: You are using pip version 20.2.4; however, version 20.3.1 is available.
# You should consider upgrading via the '/Users/syhamdani/.pyenv/versions/3.7.9/envs/PYTN/bin/python3.7 -m pip install --upgrade pip' command.

# %%
df_obes = pd.read_excel("./data/obes.xls", sheet_name="7.2", skiprows=4, skipfooter=14)
print("Num of rows:", df_obes.shape[0])
print("Num of cols:", df_obes.shape[1])
# Out:
# Num of rows: 12
# Num of cols: 10

# %%
df_obes.head()
# Out:
#   Unnamed: 0   Total  Under 16  16-24  25-34  35-44  45-54  55-64  65-74  \
# 0        NaN     NaN       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    2002/03  1275.0     400.0   65.0  136.0  289.0  216.0   94.0   52.0
# 2    2003/04  1711.0     579.0   67.0  174.0  391.0  273.0  151.0   52.0
# 3    2004/05  2035.0     547.0  107.0  287.0  487.0  364.0  174.0   36.0
# 4    2005/06  2564.0     583.0   96.0  341.0  637.0  554.0  258.0   72.0
#
#    75 and over
# 0          NaN
# 1         23.0
# 2         24.0
# 3         32.0
# 4         20.0

# %%
df_obes = df_obes.dropna().rename(columns={"Unnamed: 0": "Year"}).set_index("Year")
df_obes
# Out:
#            Total  Under 16  16-24   25-34   35-44   45-54   55-64  65-74  \
# Year
# 2002/03   1275.0     400.0   65.0   136.0   289.0   216.0    94.0   52.0
# 2003/04   1711.0     579.0   67.0   174.0   391.0   273.0   151.0   52.0
# 2004/05   2035.0     547.0  107.0   287.0   487.0   364.0   174.0   36.0
# 2005/06   2564.0     583.0   96.0   341.0   637.0   554.0   258.0   72.0
# 2006/07   3862.0     656.0  184.0   461.0  1069.0   872.0   459.0  118.0
# 2007/08   5018.0     747.0  228.0   564.0  1469.0  1198.0   598.0  157.0
# 2008/09   7988.0     775.0  322.0  1013.0  2359.0  2133.0  1099.0  221.0
# 2009/10  10571.0     632.0  361.0  1348.0  3132.0  3076.0  1555.0  378.0
# 2010/11  11574.0     525.0  375.0  1425.0  3277.0  3573.0  1820.0  456.0
# 2011/12  11736.0     495.0  391.0  1484.0  3104.0  3581.0  2119.0  468.0
# 2012/13  10957.0     556.0  356.0  1437.0  2744.0  3305.0  1965.0  495.0
#
#          75 and over
# Year
# 2002/03         23.0
# 2003/04         24.0
# 2004/05         32.0
# 2005/06         20.0
# 2006/07         43.0
# 2007/08         53.0
# 2008/09         63.0
# 2009/10         87.0
# 2010/11        115.0
# 2011/12         94.0
# 2012/13         99.0

# %%
df_obes.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
df_obes.drop(columns="Total").plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
plt.figure(figsize=(12, 6))
df_obes["Under 16"].plot(label="Children < 16y.o", legend=True)
df_obes["45-54"].plot(label="Adult", legend=True)
df_obes["35-44"].plot(label="35-44", legend=True)
plt.title("Are children getting fatter?")
plt.show()

# %%
dates = pd.date_range(start="2020-12-1", end="2020-12-15", freq="2H", tz="Asia/Jakarta")
dates
# Out:
# DatetimeIndex(['2020-12-01 00:00:00+07:00', '2020-12-01 02:00:00+07:00',
#                '2020-12-01 04:00:00+07:00', '2020-12-01 06:00:00+07:00',
#                '2020-12-01 08:00:00+07:00', '2020-12-01 10:00:00+07:00',
#                '2020-12-01 12:00:00+07:00', '2020-12-01 14:00:00+07:00',
#                '2020-12-01 16:00:00+07:00', '2020-12-01 18:00:00+07:00',
#                ...
#                '2020-12-14 06:00:00+07:00', '2020-12-14 08:00:00+07:00',
#                '2020-12-14 10:00:00+07:00', '2020-12-14 12:00:00+07:00',
#                '2020-12-14 14:00:00+07:00', '2020-12-14 16:00:00+07:00',
#                '2020-12-14 18:00:00+07:00', '2020-12-14 20:00:00+07:00',
#                '2020-12-14 22:00:00+07:00', '2020-12-15 00:00:00+07:00'],
#               dtype='datetime64[ns, Asia/Jakarta]', length=169, freq='2H')

# %%
df_dates = pd.DataFrame(dates, columns=["date"])

# %%
df_dates["score"] = np.random.randint(100, size=len(df_dates))
df_dates
# Out:
#                          date  score
# 0   2020-12-01 00:00:00+07:00     56
# 1   2020-12-01 02:00:00+07:00     79
# 2   2020-12-01 04:00:00+07:00      7
# 3   2020-12-01 06:00:00+07:00     85
# 4   2020-12-01 08:00:00+07:00     20
# ..                        ...    ...
# 164 2020-12-14 16:00:00+07:00     24
# 165 2020-12-14 18:00:00+07:00     20
# 166 2020-12-14 20:00:00+07:00     56
# 167 2020-12-14 22:00:00+07:00     98
# 168 2020-12-15 00:00:00+07:00     37
#
# [169 rows x 2 columns]

# %%
df_dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    169 non-null    datetime64[ns, Asia/Jakarta]
#  1   score   169 non-null    int64
# dtypes: datetime64[ns, Asia/Jakarta](1), int64(1)
# memory usage: 2.8 KB

# %%
df_dates = df_dates.rename(columns={"date": "datetime"}).set_index("datetime")

# %%
df_dates.head()
# Out:
#                            score
# datetime
# 2020-12-01 00:00:00+07:00     56
# 2020-12-01 02:00:00+07:00     79
# 2020-12-01 04:00:00+07:00      7
# 2020-12-01 06:00:00+07:00     85
# 2020-12-01 08:00:00+07:00     20

# %%
df_dates.index.day_name()
# Out:
# Index(['Tuesday', 'Tuesday', 'Tuesday', 'Tuesday', 'Tuesday', 'Tuesday',
#        'Tuesday', 'Tuesday', 'Tuesday', 'Tuesday',
#        ...
#        'Monday', 'Monday', 'Monday', 'Monday', 'Monday', 'Monday', 'Monday',
#        'Monday', 'Monday', 'Tuesday'],
#       dtype='object', name='datetime', length=169)

# %%
df_dates[(df_dates.index.hour == 6) & (df_dates.index.day_name() == "Sunday")]
# Out:
#                            score
# datetime
# 2020-12-06 06:00:00+07:00     72
# 2020-12-13 06:00:00+07:00     42

# %%
df_dates["2020/12/1":"2020/12/7"]
# Out:
#                            score
# datetime
# 2020-12-01 00:00:00+07:00     56
# 2020-12-01 02:00:00+07:00     79
# 2020-12-01 04:00:00+07:00      7
# 2020-12-01 06:00:00+07:00     85
# 2020-12-01 08:00:00+07:00     20
# ...                          ...
# 2020-12-07 14:00:00+07:00     84
# 2020-12-07 16:00:00+07:00      2
# 2020-12-07 18:00:00+07:00      2
# 2020-12-07 20:00:00+07:00     44
# 2020-12-07 22:00:00+07:00     89
#
# [84 rows x 1 columns]

# %%
df_dates.resample("7D").mean()
# Out:
#                                score
# datetime
# 2020-12-01 00:00:00+07:00  47.535714
# 2020-12-08 00:00:00+07:00  47.178571
# 2020-12-15 00:00:00+07:00  37.000000

# %%
df_dates["rolling_sum"] = df_dates.rolling(3).sum()
df_dates
# Out:
#                            score  rolling_sum
# datetime
# 2020-12-01 00:00:00+07:00     56          NaN
# 2020-12-01 02:00:00+07:00     79          NaN
# 2020-12-01 04:00:00+07:00      7        142.0
# 2020-12-01 06:00:00+07:00     85        171.0
# 2020-12-01 08:00:00+07:00     20        112.0
# ...                          ...          ...
# 2020-12-14 16:00:00+07:00     24        121.0
# 2020-12-14 18:00:00+07:00     20         86.0
# 2020-12-14 20:00:00+07:00     56        100.0
# 2020-12-14 22:00:00+07:00     98        174.0
# 2020-12-15 00:00:00+07:00     37        191.0
#
# [169 rows x 2 columns]

# %%
df_dates.fillna({"rolling_sum": df_dates["score"]})
# Out:
#                            score  rolling_sum
# datetime
# 2020-12-01 00:00:00+07:00     56         56.0
# 2020-12-01 02:00:00+07:00     79         79.0
# 2020-12-01 04:00:00+07:00      7        142.0
# 2020-12-01 06:00:00+07:00     85        171.0
# 2020-12-01 08:00:00+07:00     20        112.0
# ...                          ...          ...
# 2020-12-14 16:00:00+07:00     24        121.0
# 2020-12-14 18:00:00+07:00     20         86.0
# 2020-12-14 20:00:00+07:00     56        100.0
# 2020-12-14 22:00:00+07:00     98        174.0
# 2020-12-15 00:00:00+07:00     37        191.0
#
# [169 rows x 2 columns]

# %%
df_opsd = pd.read_csv("./data/opsd_germany_daily.csv")
print("Num of rows:", df_opsd.shape[0])
print("Num of cols:", df_opsd.shape[1])
display(df_opsd.head())
display(df_opsd.tail())
# Out:
# Num of rows: 4383
# Num of cols: 5
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN
#             Date  Consumption     Wind   Solar  Wind+Solar
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156

# %%
df_opsd["Date"] = pd.to_datetime(df_opsd["Date"])
df_opsd
# Out:
#            Date  Consumption     Wind   Solar  Wind+Solar
# 0    2006-01-01   1069.18400      NaN     NaN         NaN
# 1    2006-01-02   1380.52100      NaN     NaN         NaN
# 2    2006-01-03   1442.53300      NaN     NaN         NaN
# 3    2006-01-04   1457.21700      NaN     NaN         NaN
# 4    2006-01-05   1477.13100      NaN     NaN         NaN
# ...         ...          ...      ...     ...         ...
# 4378 2017-12-27   1263.94091  394.507  16.530     411.037
# 4379 2017-12-28   1299.86398  506.424  14.162     520.586
# 4380 2017-12-29   1295.08753  584.277  29.854     614.131
# 4381 2017-12-30   1215.44897  721.247   7.467     728.714
# 4382 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %%
df_opsd
# Out:
#            Date  Consumption     Wind   Solar  Wind+Solar
# 0    2006-01-01   1069.18400      NaN     NaN         NaN
# 1    2006-01-02   1380.52100      NaN     NaN         NaN
# 2    2006-01-03   1442.53300      NaN     NaN         NaN
# 3    2006-01-04   1457.21700      NaN     NaN         NaN
# 4    2006-01-05   1477.13100      NaN     NaN         NaN
# ...         ...          ...      ...     ...         ...
# 4378 2017-12-27   1263.94091  394.507  16.530     411.037
# 4379 2017-12-28   1299.86398  506.424  14.162     520.586
# 4380 2017-12-29   1295.08753  584.277  29.854     614.131
# 4381 2017-12-30   1215.44897  721.247   7.467     728.714
# 4382 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %%
df_opsd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         4383 non-null   datetime64[ns]
#  1   Consumption  4383 non-null   float64
#  2   Wind         2920 non-null   float64
#  3   Solar        2188 non-null   float64
#  4   Wind+Solar   2187 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 171.3 KB

# %%
df_opsd = df_opsd.set_index("Date")
df_opsd.index
# Out:
# DatetimeIndex(['2006-01-01', '2006-01-02', '2006-01-03', '2006-01-04',
#                '2006-01-05', '2006-01-06', '2006-01-07', '2006-01-08',
#                '2006-01-09', '2006-01-10',
#                ...
#                '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25',
#                '2017-12-26', '2017-12-27', '2017-12-28', '2017-12-29',
#                '2017-12-30', '2017-12-31'],
#               dtype='datetime64[ns]', name='Date', length=4383, freq=None)

# %%
df_opsd
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN
# 2006-01-02   1380.52100      NaN     NaN         NaN
# 2006-01-03   1442.53300      NaN     NaN         NaN
# 2006-01-04   1457.21700      NaN     NaN         NaN
# 2006-01-05   1477.13100      NaN     NaN         NaN
# ...                 ...      ...     ...         ...
# 2017-12-27   1263.94091  394.507  16.530     411.037
# 2017-12-28   1299.86398  506.424  14.162     520.586
# 2017-12-29   1295.08753  584.277  29.854     614.131
# 2017-12-30   1215.44897  721.247   7.467     728.714
# 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 4 columns]

# %%
df_opsd.index
# Out:
# DatetimeIndex(['2006-01-01', '2006-01-02', '2006-01-03', '2006-01-04',
#                '2006-01-05', '2006-01-06', '2006-01-07', '2006-01-08',
#                '2006-01-09', '2006-01-10',
#                ...
#                '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25',
#                '2017-12-26', '2017-12-27', '2017-12-28', '2017-12-29',
#                '2017-12-30', '2017-12-31'],
#               dtype='datetime64[ns]', name='Date', length=4383, freq=None)

# %%
df_opsd["year"] = df_opsd.index.year
df_opsd["month"] = df_opsd.index.month_name()
df_opsd["dayname"] = df_opsd.index.day_name()
df_opsd
# Out:
#             Consumption     Wind   Solar  Wind+Solar  year     month  \
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN  2006   January
# 2006-01-02   1380.52100      NaN     NaN         NaN  2006   January
# 2006-01-03   1442.53300      NaN     NaN         NaN  2006   January
# 2006-01-04   1457.21700      NaN     NaN         NaN  2006   January
# 2006-01-05   1477.13100      NaN     NaN         NaN  2006   January
# ...                 ...      ...     ...         ...   ...       ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  2017  December
# 2017-12-28   1299.86398  506.424  14.162     520.586  2017  December
# 2017-12-29   1295.08753  584.277  29.854     614.131  2017  December
# 2017-12-30   1215.44897  721.247   7.467     728.714  2017  December
# 2017-12-31   1107.11488  721.176  19.980     741.156  2017  December
#
#               dayname
# Date
# 2006-01-01     Sunday
# 2006-01-02     Monday
# 2006-01-03    Tuesday
# 2006-01-04  Wednesday
# 2006-01-05   Thursday
# ...               ...
# 2017-12-27  Wednesday
# 2017-12-28   Thursday
# 2017-12-29     Friday
# 2017-12-30   Saturday
# 2017-12-31     Sunday
#
# [4383 rows x 7 columns]

# %%
df_opsd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4383 entries, 2006-01-01 to 2017-12-31
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Consumption  4383 non-null   float64
#  1   Wind         2920 non-null   float64
#  2   Solar        2188 non-null   float64
#  3   Wind+Solar   2187 non-null   float64
#  4   year         4383 non-null   int64
#  5   month        4383 non-null   object
#  6   dayname      4383 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 273.9+ KB

# %%
# df_opsd.loc[df_opsd.index.dayofweek == 0]
df_opsd.loc[df_opsd.dayname == "Monday"]
# Out:
#             Consumption     Wind   Solar  Wind+Solar  year     month dayname
# Date
# 2006-01-02   1380.52100      NaN     NaN         NaN  2006   January  Monday
# 2006-01-09   1529.32300      NaN     NaN         NaN  2006   January  Monday
# 2006-01-16   1563.73800      NaN     NaN         NaN  2006   January  Monday
# 2006-01-23   1569.69100      NaN     NaN         NaN  2006   January  Monday
# 2006-01-30   1554.72200      NaN     NaN         NaN  2006   January  Monday
# ...                 ...      ...     ...         ...   ...       ...     ...
# 2017-11-27   1602.17797  743.280  21.983     765.263  2017  November  Monday
# 2017-12-04   1620.97758  479.798  10.747     490.545  2017  December  Monday
# 2017-12-11   1614.15862  415.109   5.669     420.778  2017  December  Monday
# 2017-12-18   1578.69079  134.843  15.897     150.740  2017  December  Monday
# 2017-12-25   1111.28338  587.810  15.765     603.575  2017  December  Monday
#
# [626 rows x 7 columns]

# %%
set_years = set(df_opsd.index.year)
print("Range of the year:", len(set_years), set_years)
# Out:
# Range of the year: 12 {2016, 2017, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015}

# %%
df_opsd
# Out:
#             Consumption     Wind   Solar  Wind+Solar  year     month  \
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN  2006   January
# 2006-01-02   1380.52100      NaN     NaN         NaN  2006   January
# 2006-01-03   1442.53300      NaN     NaN         NaN  2006   January
# 2006-01-04   1457.21700      NaN     NaN         NaN  2006   January
# 2006-01-05   1477.13100      NaN     NaN         NaN  2006   January
# ...                 ...      ...     ...         ...   ...       ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  2017  December
# 2017-12-28   1299.86398  506.424  14.162     520.586  2017  December
# 2017-12-29   1295.08753  584.277  29.854     614.131  2017  December
# 2017-12-30   1215.44897  721.247   7.467     728.714  2017  December
# 2017-12-31   1107.11488  721.176  19.980     741.156  2017  December
#
#               dayname
# Date
# 2006-01-01     Sunday
# 2006-01-02     Monday
# 2006-01-03    Tuesday
# 2006-01-04  Wednesday
# 2006-01-05   Thursday
# ...               ...
# 2017-12-27  Wednesday
# 2017-12-28   Thursday
# 2017-12-29     Friday
# 2017-12-30   Saturday
# 2017-12-31     Sunday
#
# [4383 rows x 7 columns]

# %%
df_opsd.groupby("year")[["Consumption", "Wind", "Solar"]].mean()
# Out:
#       Consumption        Wind      Solar
# year
# 2006  1339.913797         NaN        NaN
# 2007  1360.635197         NaN        NaN
# 2008  1354.018787         NaN        NaN
# 2009  1259.554597         NaN        NaN
# 2010  1338.599178   98.388430        NaN
# 2011  1328.257770  120.969646        NaN
# 2012  1282.991131  125.307833  76.194896
# 2013  1269.416036  129.309129  81.431901
# 2014  1381.273482  140.405692  89.527017
# 2015  1384.286474  212.243819  95.635995
# 2016  1382.315175  210.404716  94.433945
# 2017  1382.839368  281.280452  98.308611

# %%
monthly_avg_opsd = df_opsd.groupby(["year", "month"])[["Consumption", "Wind", "Solar"]].mean()
monthly_avg_opsd
# Out:
#                 Consumption        Wind       Solar
# year month
# 2006 April      1275.058900         NaN         NaN
#      August     1241.188774         NaN         NaN
#      December   1385.686355         NaN         NaN
#      February   1467.106893         NaN         NaN
#      January    1461.442065         NaN         NaN
# ...                     ...         ...         ...
# 2017 March      1422.456871  299.807516  104.216677
#      May        1323.081097  182.150516  165.172774
#      November   1477.990818  341.966700   27.701467
#      October    1366.297385  402.583774   68.727645
#      September  1335.952031  209.591000  102.643033
#
# [144 rows x 3 columns]

# %%
monthly_avg_opsd.index.names
# Out:
# FrozenList(['year', 'month'])

# %%
monthly_avg_opsd.loc[
    ([2006, 2007], ["January", "February"]),
    ["Consumption", "Wind", "Solar"]
]
# Out:
#                Consumption  Wind  Solar
# year month
# 2006 January   1461.442065   NaN    NaN
#      February  1467.106893   NaN    NaN
# 2007 January   1467.058032   NaN    NaN
#      February  1434.484357   NaN    NaN

# %% [markdown]
# ```len(), print(), np.random.randint(), int(), str(), float(), plt.show()```   -> function
#
# ```df_opsd.index.day_name()``` -> method

# %%
plt.figure(figsize=(12, 6))
df_opsd.loc[df_opsd.index.month < 3, "Consumption"].plot()
plt.show()

# %%
plt.figure(figsize=(12, 10))
df_opsd["Consumption"].plot(marker=".", alpha=.5, linestyle="None")
plt.show()

# %%
df_opsd["Wind+Solar"].plot(kind="box", figsize=(9, 9))
# Out:
# <AxesSubplot:>

# %%
df_opsd.boxplot("Consumption", by="month", figsize=(12, 6));

# %%
df_opsd.boxplot("Consumption", by="dayname", figsize=(12, 6));

# %%
dates = pd.DataFrame(
    [pd.date_range("2020-12-1", "2020-12-17"),
     pd.date_range("2019-11-14", "2019-11-30")],
    index=["d1", "d2"]
).T
dates
# Out:
#            d1         d2
# 0  2020-12-01 2019-11-14
# 1  2020-12-02 2019-11-15
# 2  2020-12-03 2019-11-16
# 3  2020-12-04 2019-11-17
# 4  2020-12-05 2019-11-18
# 5  2020-12-06 2019-11-19
# 6  2020-12-07 2019-11-20
# 7  2020-12-08 2019-11-21
# 8  2020-12-09 2019-11-22
# 9  2020-12-10 2019-11-23
# 10 2020-12-11 2019-11-24
# 11 2020-12-12 2019-11-25
# 12 2020-12-13 2019-11-26
# 13 2020-12-14 2019-11-27
# 14 2020-12-15 2019-11-28
# 15 2020-12-16 2019-11-29
# 16 2020-12-17 2019-11-30

# %%
dates["d2"].dt.day - dates["d1"].dt.day
# Out:
# 0     13
# 1     13
# 2     13
# 3     13
# 4     13
# 5     13
# 6     13
# 7     13
# 8     13
# 9     13
# 10    13
# 11    13
# 12    13
# 13    13
# 14    13
# 15    13
# 16    13
# dtype: int64

# %% [markdown]
# ## Users Behavior Data

# %%
df = pd.read_csv("data/ecommerce-user-behavior.csv")

# %%
df.shape
# Out:
# (42448764, 9)

# %%
df.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:00:00 UTC       view    44600062  2103807459595387724
# 1  2019-10-01 00:00:00 UTC       view     3900821  2053013552326770905
# 2  2019-10-01 00:00:01 UTC       view    17200506  2053013559792632471
# 3  2019-10-01 00:00:01 UTC       view     1307067  2053013558920217191
# 4  2019-10-01 00:00:04 UTC       view     1004237  2053013555631882655
#
#                          category_code     brand    price    user_id  \
# 0                                  NaN  shiseido    35.79  541312140
# 1  appliances.environment.water_heater      aqua    33.20  554748717
# 2           furniture.living_room.sofa       NaN   543.10  519107250
# 3                   computers.notebook    lenovo   251.74  550050854
# 4               electronics.smartphone     apple  1081.98  535871217
#
#                            user_session
# 0  72d76fde-8bb3-4e00-8c23-a032dfed738c
# 1  9333dfbd-b87a-4708-9857-6336556b0fcc
# 2  566511c2-e2e3-422b-b695-cf8e6e792ca8
# 3  7c90fc70-0e80-4590-96f3-13c02c18c713
# 4  c6bd7419-2748-4c56-95b4-8cec9ff8b80d

# %%
(df["event_type"].value_counts() / df.shape[0]).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df["event_time"] = pd.to_datetime(df.event_time)
df.info()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-289-e32e04553fb2> in <module>
# ----> 1 df["event_time"] = pd.to_datetime(df.event_time)
#       2 df.info()
#
# ~/.pyenv/versions/3.7.9/envs/PYTN/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     797                 result = result.tz_localize(tz)
#     798     elif isinstance(arg, ABCSeries):
# --> 799         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#     800         if not cache_array.empty:
#     801             result = arg.map(cache_array)
#
# ~/.pyenv/versions/3.7.9/envs/PYTN/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     168         unique_dates = unique(arg)
#     169         if len(unique_dates) < len(arg):
# --> 170             cache_dates = convert_listlike(unique_dates, format)
#     171             cache_array = Series(cache_dates, index=unique_dates)
#     172     return cache_array
#
# ~/.pyenv/versions/3.7.9/envs/PYTN/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     464             errors=errors,
#     465             require_iso8601=require_iso8601,
# --> 466             allow_object=True,
#     467         )
#     468
#
# ~/.pyenv/versions/3.7.9/envs/PYTN/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2048             dayfirst=dayfirst,
#    2049             yearfirst=yearfirst,
# -> 2050             require_iso8601=require_iso8601,
#    2051         )
#    2052     except ValueError as e:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/.pyenv/versions/3.7.9/envs/PYTN/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1372         return parser(parserinfo).parse(timestr, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#    1376
#
# ~/.pyenv/versions/3.7.9/envs/PYTN/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     644                                                       second=0, microsecond=0)
#     645
# --> 646         res, skipped_tokens = self._parse(timestr, **kwargs)
#     647
#     648         if res is None:
#
# ~/.pyenv/versions/3.7.9/envs/PYTN/lib/python3.7/site-packages/dateutil/parser/_parser.py in _parse(self, timestr, dayfirst, yearfirst, fuzzy, fuzzy_with_tokens)
#     723
#     724         res = self._result()
# --> 725         l = _timelex.split(timestr)         # Splits the timestr into tokens
#     726
#     727         skipped_idxs = []
#
# ~/.pyenv/versions/3.7.9/envs/PYTN/lib/python3.7/site-packages/dateutil/parser/_parser.py in split(cls, s)
#     205     @classmethod
#     206     def split(cls, s):
# --> 207         return list(cls(s))
#     208
#     209     @classmethod
#
# ~/.pyenv/versions/3.7.9/envs/PYTN/lib/python3.7/site-packages/dateutil/parser/_parser.py in __next__(self)
#     194
#     195     def __next__(self):
# --> 196         token = self.get_token()
#     197         if token is None:
#     198             raise StopIteration
#
# ~/.pyenv/versions/3.7.9/envs/PYTN/lib/python3.7/site-packages/dateutil/parser/_parser.py in get_token(self)
#     130                 else:
#     131                     break  # emit token
# --> 132             elif state == 'a':
#     133                 # If we've already started reading a word, we keep reading
#     134                 # letters until we find something that's not part of a word.
#
# KeyboardInterrupt:

# %%
df.groupby("user_id")["event_time"].min()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-287-f8f8bc33c0c8> in <module>
# ----> 1 df.groupby("user_id")["event_time"].min()
#
# ~/.pyenv/versions/3.7.9/envs/PYTN/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in min(self, numeric_only, min_count)
#    1550     def min(self, numeric_only: bool = False, min_count: int = -1):
#    1551         return self._agg_general(
# -> 1552             numeric_only=numeric_only, min_count=min_count, alias="min", npfunc=np.min
#    1553         )
#    1554
#
# ~/.pyenv/versions/3.7.9/envs/PYTN/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc)
#    1013
#    1014         # apply a non-cython aggregation
# -> 1015         result = self.aggregate(lambda x: npfunc(x, axis=self.axis))
#    1016         return result
#    1017
#
# ~/.pyenv/versions/3.7.9/envs/PYTN/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     259             try:
#     260                 return self._python_agg_general(
# --> 261                     func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#     262                 )
#     263             except (ValueError, KeyError):
#
# ~/.pyenv/versions/3.7.9/envs/PYTN/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_agg_general(self, func, engine, engine_kwargs, *args, **kwargs)
#    1081                 try:
#    1082                     # if this function is invalid for this dtype, we will ignore it.
# -> 1083                     result, counts = self.grouper.agg_series(obj, f)
#    1084                 except TypeError:
#    1085                     continue
#
# ~/.pyenv/versions/3.7.9/envs/PYTN/lib/python3.7/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, engine, engine_kwargs, *args, **kwargs)
#     642
#     643         try:
# --> 644             return self._aggregate_series_fast(obj, func)
#     645         except ValueError as err:
#     646             if "Function does not reduce" in str(err):
#
# ~/.pyenv/versions/3.7.9/envs/PYTN/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _aggregate_series_fast(self, obj, func)
#     667         group_index = algorithms.take_nd(group_index, indexer, allow_fill=False)
#     668         grouper = libreduction.SeriesGrouper(obj, func, group_index, ngroups, dummy)
# --> 669         result, counts = grouper.get_result()
#     670         return result, counts
#     671
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction._BaseGrouper._apply_to_group()
#
# ~/.pyenv/versions/3.7.9/envs/PYTN/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    1058         func = self._is_builtin_func(func)
#    1059         if engine != "numba":
# -> 1060             f = lambda x: func(x, *args, **kwargs)
#    1061
#    1062         # iterate through "columns" ex exclusions to populate output dict
#
# KeyboardInterrupt:
